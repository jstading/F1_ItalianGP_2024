# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
leclerc = pd.read_csv('leclerc_car_data_ItalianGP_2024.csv')

# %%
leclerc.head()
# Out:
#    brake                              date  driver_number  drs  meeting_key  \
# 0    104  2024-08-31 15:07:36.009000+00:00             16    8         1244
# 1      0  2024-09-01 12:08:56.653000+00:00             16    0         1244
# 2      0  2024-09-01 12:08:56.893000+00:00             16    0         1244
# 3      0  2024-09-01 12:08:57.133000+00:00             16    0         1244
# 4      0  2024-09-01 12:08:57.413000+00:00             16    0         1244
#
#    n_gear  rpm  session_key  speed  throttle
# 0       0    0         9590      0       104
# 1       0    0         9590      0         0
# 2       0    0         9590      0         0
# 3       0    0         9590      0         0
# 4       0    0         9590      0         0

# %%
leclerc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29200 entries, 0 to 29199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brake          29200 non-null  int64
#  1   date           29200 non-null  object
#  2   driver_number  29200 non-null  int64
#  3   drs            29200 non-null  int64
#  4   meeting_key    29200 non-null  int64
#  5   n_gear         29200 non-null  int64
#  6   rpm            29200 non-null  int64
#  7   session_key    29200 non-null  int64
#  8   speed          29200 non-null  int64
#  9   throttle       29200 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 2.2+ MB

# %%
leclerc['speed']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 29195    115
# 29196    113
# 29197    111
# 29198    110
# 29199    109
# Name: speed, Length: 29200, dtype: int64

# %%
sns.distplot(leclerc['speed'])
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_7944\3731049912.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['speed'])
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sns.distplot(leclerc['rpm'])
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_7944\1309985233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['rpm'])
# <Axes: xlabel='rpm', ylabel='Density'>

# %%
sns.jointplot(x='speed', y='rpm', data=leclerc)

# %%
print(leclerc.loc[[11093]])
# Out:
#        brake                              date  driver_number  drs  \
# 11093    100  2024-09-01 13:00:00.180000+00:00             16    1
#
#        meeting_key  n_gear    rpm  session_key  speed  throttle
# 11093         1244       1  10546         9590      0        37

# %%
leclerc = leclerc.loc[11093:]

# %%
leclerc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18107 entries, 11093 to 29199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brake          18107 non-null  int64
#  1   date           18107 non-null  object
#  2   driver_number  18107 non-null  int64
#  3   drs            18107 non-null  int64
#  4   meeting_key    18107 non-null  int64
#  5   n_gear         18107 non-null  int64
#  6   rpm            18107 non-null  int64
#  7   session_key    18107 non-null  int64
#  8   speed          18107 non-null  int64
#  9   throttle       18107 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 1.4+ MB

# %%
sns.distplot(leclerc['speed'])
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_7944\3731049912.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['speed'])
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sns.distplot(leclerc['rpm'])
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_7944\1309985233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['rpm'])
# <Axes: xlabel='rpm', ylabel='Density'>

# %%
sns.jointplot(x='speed', y='rpm', data=leclerc)
