# %% [markdown]
# Italian GP 2024 - Charles Leclerc analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
leclerc = pd.read_csv('leclerc_car_data_ItalianGP_2024.csv')

# %%
leclerc.head()
# Out:
#    brake                              date  driver_number  drs  meeting_key  \
# 0    104  2024-08-31 15:07:36.009000+00:00             16    8         1244
# 1      0  2024-09-01 12:08:56.653000+00:00             16    0         1244
# 2      0  2024-09-01 12:08:56.893000+00:00             16    0         1244
# 3      0  2024-09-01 12:08:57.133000+00:00             16    0         1244
# 4      0  2024-09-01 12:08:57.413000+00:00             16    0         1244
#
#    n_gear  rpm  session_key  speed  throttle
# 0       0    0         9590      0       104
# 1       0    0         9590      0         0
# 2       0    0         9590      0         0
# 3       0    0         9590      0         0
# 4       0    0         9590      0         0

# %%
leclerc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29200 entries, 0 to 29199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brake          29200 non-null  int64
#  1   date           29200 non-null  object
#  2   driver_number  29200 non-null  int64
#  3   drs            29200 non-null  int64
#  4   meeting_key    29200 non-null  int64
#  5   n_gear         29200 non-null  int64
#  6   rpm            29200 non-null  int64
#  7   session_key    29200 non-null  int64
#  8   speed          29200 non-null  int64
#  9   throttle       29200 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 2.2+ MB

# %%
print(leclerc.loc[[11093]])
# Out:
#        brake                              date  driver_number  drs  \
# 11093    100  2024-09-01 13:00:00.180000+00:00             16    1
#
#        meeting_key  n_gear    rpm  session_key  speed  throttle
# 11093         1244       1  10546         9590      0        37

# %%
leclerc = leclerc.loc[11093:]

# %%
leclerc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18107 entries, 11093 to 29199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brake          18107 non-null  int64
#  1   date           18107 non-null  object
#  2   driver_number  18107 non-null  int64
#  3   drs            18107 non-null  int64
#  4   meeting_key    18107 non-null  int64
#  5   n_gear         18107 non-null  int64
#  6   rpm            18107 non-null  int64
#  7   session_key    18107 non-null  int64
#  8   speed          18107 non-null  int64
#  9   throttle       18107 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 1.4+ MB

# %%
sns.distplot(leclerc['speed'], color='red')
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_22484\2065911527.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['speed'], color='red')
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sns.distplot(leclerc['rpm'], color='red')
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_22484\23226944.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(leclerc['rpm'], color='red')
# <Axes: xlabel='rpm', ylabel='Density'>

# %%
sns.jointplot(x='rpm', y='speed', data=leclerc, color='red')

# %%
leclerc['date']
# Out:
# 11093    2024-09-01 13:00:00.180000+00:00
# 11094    2024-09-01 13:00:00.379000+00:00
# 11095    2024-09-01 13:00:00.619000+00:00
# 11096    2024-09-01 13:00:00.819000+00:00
# 11097    2024-09-01 13:00:00.979000+00:00
#                        ...
# 29195    2024-09-01 14:20:33.395000+00:00
# 29196    2024-09-01 14:20:33.635000+00:00
# 29197    2024-09-01 14:20:33.955000+00:00
# 29198    2024-09-01 14:20:34.156000+00:00
# 29199    2024-09-01 14:20:34.436000+00:00
# Name: date, Length: 18107, dtype: object

# %%
leclerc['date'] = pd.to_datetime(leclerc['date'])

# %%
leclerc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18107 entries, 11093 to 29199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brake          18107 non-null  int64
#  1   date           18107 non-null  datetime64[ns, UTC]
#  2   driver_number  18107 non-null  int64
#  3   drs            18107 non-null  int64
#  4   meeting_key    18107 non-null  int64
#  5   n_gear         18107 non-null  int64
#  6   rpm            18107 non-null  int64
#  7   session_key    18107 non-null  int64
#  8   speed          18107 non-null  int64
#  9   throttle       18107 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(9)
# memory usage: 1.4 MB

# %%
sns.pairplot(leclerc)
# Out:
# C:\Users\John\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(x='date', y='speed', data=leclerc)
# Out:
# <Axes: xlabel='date', ylabel='speed'>

# %%
leclerc.head()
# Out:
#        brake                             date  driver_number  drs  \
# 11093    100 2024-09-01 13:00:00.180000+00:00             16    1
# 11094    100 2024-09-01 13:00:00.379000+00:00             16    1
# 11095    100 2024-09-01 13:00:00.619000+00:00             16    1
# 11096    100 2024-09-01 13:00:00.819000+00:00             16    1
# 11097    100 2024-09-01 13:00:00.979000+00:00             16    1
#
#        meeting_key  n_gear    rpm  session_key  speed  throttle
# 11093         1244       1  10546         9590      0        37
# 11094         1244       1  10562         9590      0        37
# 11095         1244       1  10580         9590      0        37
# 11096         1244       1  10573         9590      0        37
# 11097         1244       1  10595         9590      0        37

# %%
print(leclerc['date']<'2024-09-01 13:00:01.000000+00:00')
# Out:
# 11093     True
# 11094     True
# 11095     True
# 11096     True
# 11097     True
#          ...
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# Name: date, Length: 18107, dtype: bool

# %%
leclerc['date']
# Out:
# 11093   2024-09-01 13:00:00.180000+00:00
# 11094   2024-09-01 13:00:00.379000+00:00
# 11095   2024-09-01 13:00:00.619000+00:00
# 11096   2024-09-01 13:00:00.819000+00:00
# 11097   2024-09-01 13:00:00.979000+00:00
#                       ...
# 29195   2024-09-01 14:20:33.395000+00:00
# 29196   2024-09-01 14:20:33.635000+00:00
# 29197   2024-09-01 14:20:33.955000+00:00
# 29198   2024-09-01 14:20:34.156000+00:00
# 29199   2024-09-01 14:20:34.436000+00:00
# Name: date, Length: 18107, dtype: datetime64[ns, UTC]
